# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Extracting features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                  Title  \
# 0     JANUARY          3             The Grudge
# 1     JANUARY         10             Underwater
# 2     JANUARY         10            Like a Boss
# 3     JANUARY         10          Three Christs
# 4     JANUARY         10      Inherit the Viper
# ..        ...        ...                    ...
# 264  DECEMBER         25       We Can Be Heroes
# 265  DECEMBER         25      News of the World
# 266  DECEMBER         25  One Night in Miami...
# 267  DECEMBER         25  Promising Young Woman
# 268  DECEMBER         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ..                                                 ...
# 264                     Netflix / Troublemaker Studios
# 265        Universal Pictures / Perfect World Pictures
# 266                                     Amazon Studios
# 267          Focus Features / FilmNation Entertainment
# 268                             Netflix / Bron Studios
#
#                                          Cast and crew   Ref.
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...    [2]
# 1    William Eubank (director); Brian Duffield, Ada...    [3]
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...    [4]
# 3    Jon Avnet (director/screenplay); Eric Nazarian...    NaN
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...    [5]
# ..                                                 ...    ...
# 264  Robert Rodriguez (director/screenplay); Priyan...  [237]
# 265  Paul Greengrass (director/screenplay); Luke Da...  [238]
# 266  Regina King (director); Kemp Powers (screenpla...  [239]
# 267  Emerald Fennell (director/screenplay); Carey M...  [240]
# 268  Kornél Mundruczó (director); Kata Wéber (scree...  [241]
#
# [269 rows x 6 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 264       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 265      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 266  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 267  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 268      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [269 rows x 2 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in d:\users\mani\anaconda3\lib\site-packages (1.7.1)
# Requirement already satisfied: requests in d:\users\mani\anaconda3\lib\site-packages (from tmdbv3api) (2.22.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\mani\anaconda3\lib\site-packages (from requests->tmdbv3api) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in d:\users\mani\anaconda3\lib\site-packages (from requests->tmdbv3api) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in d:\users\mani\anaconda3\lib\site-packages (from requests->tmdbv3api) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\users\mani\anaconda3\lib\site-packages (from requests->tmdbv3api) (1.24.2)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '5492165c61b1a21c06eb3a3b578a6339'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# D:\Users\mani\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 264       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 265      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 266  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 267  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 268      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres
# 0                   Horror Mystery Thriller
# 1    Action Horror Science Fiction Thriller
# 2                                    Comedy
# 3                                     Drama
# 4                      Drama Thriller Crime
# ..                                      ...
# 264      Action Fantasy Family Drama Comedy
# 265          Action Adventure Drama Western
# 266                                   Drama
# 267                    Thriller Crime Drama
# 268                                   Drama
#
# [269 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# D:\Users\mani\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# D:\Users\mani\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 264       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 265      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 266  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 267  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 268      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres     director_name  \
# 0                   Horror Mystery Thriller     Nicolas Pesce
# 1    Action Horror Science Fiction Thriller    William Eubank
# 2                                    Comedy     Miguel Arteta
# 3                                     Drama         Jon Avnet
# 4                      Drama Thriller Crime    Anthony Jerjen
# ..                                      ...               ...
# 264      Action Fantasy Family Drama Comedy  Robert Rodriguez
# 265          Action Adventure Drama Western   Paul Greengrass
# 266                                   Drama       Regina King
# 267                    Thriller Crime Drama   Emerald Fennell
# 268                                   Drama  Kornél Mundruczó
#
#               actor_1_name       actor_2_name     actor_3_name
# 0       Andrea Riseborough      Demián Bichir         John Cho
# 1          Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2          Tiffany Haddish         Rose Byrne      Salma Hayek
# 3             Richard Gere     Peter Dinklage   Walton Goggins
# 4            Josh Hartnett  Margarita Levieva   Chandler Riggs
# ..                     ...                ...              ...
# 264  Priyanka Chopra Jonas       Pedro Pascal    YaYa Gosselin
# 265              Tom Hanks      Helena Zengel              NaN
# 266      Kingsley Ben-Adir          Eli Goree      Aldis Hodge
# 267         Carey Mulligan         Bo Burnham      Alison Brie
# 268          Vanessa Kirby       Shia LaBeouf     Molly Parker
#
# [269 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 264  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 265   Paul Greengrass              Tom Hanks      Helena Zengel
# 266       Regina King      Kingsley Ben-Adir          Eli Goree
# 267   Emerald Fennell         Carey Mulligan         Bo Burnham
# 268  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# 2        Salma Hayek                                  Comedy
# 3     Walton Goggins                                   Drama
# 4     Chandler Riggs                    Drama Thriller Crime
# ..               ...                                     ...
# 264    YaYa Gosselin      Action Fantasy Family Drama Comedy
# 265              NaN          Action Adventure Drama Western
# 266      Aldis Hodge                                   Drama
# 267      Alison Brie                    Thriller Crime Drama
# 268     Molly Parker                                   Drama
#
#                movie_title
# 0               The Grudge
# 1               Underwater
# 2              Like a Boss
# 3            Three Christs
# 4        Inherit the Viper
# ..                     ...
# 264       We Can Be Heroes
# 265      News of the World
# 266  One Night in Miami...
# 267  Promising Young Woman
# 268      Pieces of a Woman
#
# [269 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      3
# actor_3_name     26
# genres            0
# movie_title       0
# comb             26
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# D:\Users\mani\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 263       Pete Docter             Jamie Foxx           Tina Fey
# 264  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 266       Regina King      Kingsley Ben-Adir          Eli Goree
# 267   Emerald Fennell         Carey Mulligan         Bo Burnham
# 268  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                       genres  \
# 0           John Cho                      Horror Mystery Thriller
# 1    Jessica Henwick       Action Horror Science Fiction Thriller
# 2        Salma Hayek                                       Comedy
# 3     Walton Goggins                                        Drama
# 4     Chandler Riggs                         Drama Thriller Crime
# ..               ...                                          ...
# 263    Graham Norton  Family Animation Comedy Drama Music Fantasy
# 264    YaYa Gosselin           Action Fantasy Family Drama Comedy
# 266      Aldis Hodge                                        Drama
# 267      Alison Brie                         Thriller Crime Drama
# 268     Molly Parker                                        Drama
#
#                movie_title                                               comb
# 0               the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1               underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2              like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3            three christs  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4        inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                     ...                                                ...
# 263                   soul  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 264       we can be heroes  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 266  one night in miami...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 267  promising young woman  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 268      pieces of a woman  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [243 rows x 7 columns]

# %%
old_df = pd.read_csv('datasets/final_data.csv')

# %%
old_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5867  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5868            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5869              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5870   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5871         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4                  unknown                               Documentary
# ...                    ...                                       ...
# 5867         Rashida Jones  Animation Action Adventure Comedy Family
# 5868         Florence Pugh                             Drama Romance
# 5869           Mark Strong                 War Drama Action Thriller
# 5870           Brie Larson                       Drama Crime History
# 5871           Aldis Hodge                                     Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5867                                  spies in disguise
# 5868                                       little women
# 5869                                               1917
# 5870                                         just mercy
# 5871                                           clemency
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5867  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5868  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5869  George MacKay Dean-Charles Chapman Mark Strong...
# 5870  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5871  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5872 rows x 7 columns]

# %%
old_df = old_df.append(new_df20,ignore_index=True)

# %%
old_df
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         James Cameron            CCH Pounder  Joel David Moore
# 1        Gore Verbinski            Johnny Depp     Orlando Bloom
# 2            Sam Mendes        Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan              Tom Hardy    Christian Bale
# 4           Doug Walker            Doug Walker        Rob Walker
# ...                 ...                    ...               ...
# 6110        Pete Docter             Jamie Foxx          Tina Fey
# 6111   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 6112        Regina King      Kingsley Ben-Adir         Eli Goree
# 6113    Emerald Fennell         Carey Mulligan        Bo Burnham
# 6114   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                                       genres  \
# 0                Wes Studi              Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                     Action Adventure Fantasy
# 2         Stephanie Sigman                    Action Adventure Thriller
# 3     Joseph Gordon-Levitt                              Action Thriller
# 4                  unknown                                  Documentary
# ...                    ...                                          ...
# 6110         Graham Norton  Family Animation Comedy Drama Music Fantasy
# 6111         YaYa Gosselin           Action Fantasy Family Drama Comedy
# 6112           Aldis Hodge                                        Drama
# 6113           Alison Brie                         Thriller Crime Drama
# 6114          Molly Parker                                        Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6110                                               soul
# 6111                                   we can be heroes
# 6112                              one night in miami...
# 6113                              promising young woman
# 6114                                  pieces of a woman
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6110  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 6111  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 6112  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 6113  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 6114  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [6115 rows x 7 columns]

# %% [markdown]
# ## Extracting features of 2021 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"

# %%
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# D:\Users\mani\Anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
df
# Out:
#                                         Cast and crew   Opening  Opening.1  \
# 0   Ricky Staub (director/screenplay); Dan Walser ...     APRIL        2.0
# 1   Evan Spiliotopoulos (director/screenplay); Jef...     APRIL        2.0
# 2   Vaughn Stein (director); David Murray (screenp...     APRIL        2.0
# 3   Emma Seligman (director/screenplay); Rachel Se...     APRIL        2.0
# 4   Neil Burger (director/screenplay); Tye Sherida...     APRIL        9.0
# ..                                                ...       ...        ...
# 80  Erwin brothers (directors); David Aaron, Jon E...  DECEMBER       10.0
# 81  Jon Watts (director); Chris McKenna, Erik Somm...  DECEMBER       17.0
# 82  Lana Wachowski (director/screenplay); Aleksand...  DECEMBER       22.0
# 83  Garth Jennings (director/screenplay); Matthew ...  DECEMBER       22.0
# 84                                                NaN  DECEMBER        NaN
#
#                                    Production company  Ref   Ref.  \
# 0                                             Netflix  NaN   [50]
# 1                  Screen Gems / Ghost House Pictures  NaN   [51]
# 2                              Vertical Entertainment  NaN   [52]
# 3                                              Utopia  NaN    NaN
# 4                      Lionsgate / Thunder Road Films  NaN    NaN
# ..                                                ...  ...    ...
# 80                                          Lionsgate  NaN  [108]
# 81                 Columbia Pictures / Marvel Studios  NaN  [109]
# 82  HBO Max / Warner Bros. Pictures / Village Road...  NaN  [110]
# 83                  Universal Pictures / Illumination  NaN  [111]
# 84                                                NaN  NaN    NaN
#
#                                        Title Unnamed: 0  \
# 0                            Concrete Cowboy        NaN
# 1                                 The Unholy        NaN
# 2                      Every Breath You Take        NaN
# 3                                 Shiva Baby        NaN
# 4                                   Voyagers        NaN
# ..                                       ...        ...
# 80  American Underdog: The Kurt Warner Story        NaN
# 81                   Spider-Man: No Way Home        NaN
# 82               Untitled fourth Matrix film        NaN
# 83                                    Sing 2        NaN
# 84                                       NaN        NaN
#
#    Wikimedia Commons has media related to Films of the United States, 2021.
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
#
# [85 rows x 9 columns]

# %%
df_2021 = df[['Title','Cast and crew']]

# %%
df_2021
# Out:
#                                        Title  \
# 0                            Concrete Cowboy
# 1                                 The Unholy
# 2                      Every Breath You Take
# 3                                 Shiva Baby
# 4                                   Voyagers
# ..                                       ...
# 80  American Underdog: The Kurt Warner Story
# 81                   Spider-Man: No Way Home
# 82               Untitled fourth Matrix film
# 83                                    Sing 2
# 84                                       NaN
#
#                                         Cast and crew
# 0   Ricky Staub (director/screenplay); Dan Walser ...
# 1   Evan Spiliotopoulos (director/screenplay); Jef...
# 2   Vaughn Stein (director); David Murray (screenp...
# 3   Emma Seligman (director/screenplay); Rachel Se...
# 4   Neil Burger (director/screenplay); Tye Sherida...
# ..                                                ...
# 80  Erwin brothers (directors); David Aaron, Jon E...
# 81  Jon Watts (director); Chris McKenna, Erik Somm...
# 82  Lana Wachowski (director/screenplay); Aleksand...
# 83  Garth Jennings (director/screenplay); Matthew ...
# 84                                                NaN
#
# [85 rows x 2 columns]

# %%
df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))
# Out:
# D:\Users\mani\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2021
# Out:
#                                        Title  \
# 0                            Concrete Cowboy
# 1                                 The Unholy
# 2                      Every Breath You Take
# 3                                 Shiva Baby
# 4                                   Voyagers
# ..                                       ...
# 80  American Underdog: The Kurt Warner Story
# 81                   Spider-Man: No Way Home
# 82               Untitled fourth Matrix film
# 83                                    Sing 2
# 84                                       NaN
#
#                                         Cast and crew  \
# 0   Ricky Staub (director/screenplay); Dan Walser ...
# 1   Evan Spiliotopoulos (director/screenplay); Jef...
# 2   Vaughn Stein (director); David Murray (screenp...
# 3   Emma Seligman (director/screenplay); Rachel Se...
# 4   Neil Burger (director/screenplay); Tye Sherida...
# ..                                                ...
# 80  Erwin brothers (directors); David Aaron, Jon E...
# 81  Jon Watts (director); Chris McKenna, Erik Somm...
# 82  Lana Wachowski (director/screenplay); Aleksand...
# 83  Garth Jennings (director/screenplay); Matthew ...
# 84                                                NaN
#
#                                       genres
# 0                              Drama Western
# 1                                     Horror
# 2                                   Thriller
# 3                               Comedy Drama
# 4                   Science Fiction Thriller
# ..                                       ...
# 80                                     Drama
# 81  Action Adventure Science Fiction Fantasy
# 82                                       NaN
# 83             Music Animation Comedy Family
# 84                                       NaN
#
# [85 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# D:\Users\mani\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# D:\Users\mani\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# D:\Users\mani\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(str(x)))
# Out:
# D:\Users\mani\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2021
# Out:
#                                        Title  \
# 0                            Concrete Cowboy
# 1                                 The Unholy
# 2                      Every Breath You Take
# 3                                 Shiva Baby
# 4                                   Voyagers
# ..                                       ...
# 80  American Underdog: The Kurt Warner Story
# 81                   Spider-Man: No Way Home
# 82               Untitled fourth Matrix film
# 83                                    Sing 2
# 84                                       NaN
#
#                                         Cast and crew  \
# 0   Ricky Staub (director/screenplay); Dan Walser ...
# 1   Evan Spiliotopoulos (director/screenplay); Jef...
# 2   Vaughn Stein (director); David Murray (screenp...
# 3   Emma Seligman (director/screenplay); Rachel Se...
# 4   Neil Burger (director/screenplay); Tye Sherida...
# ..                                                ...
# 80  Erwin brothers (directors); David Aaron, Jon E...
# 81  Jon Watts (director); Chris McKenna, Erik Somm...
# 82  Lana Wachowski (director/screenplay); Aleksand...
# 83  Garth Jennings (director/screenplay); Matthew ...
# 84                                                NaN
#
#                                       genres        director_name  \
# 0                              Drama Western          Ricky Staub
# 1                                     Horror  Evan Spiliotopoulos
# 2                                   Thriller         Vaughn Stein
# 3                               Comedy Drama        Emma Seligman
# 4                   Science Fiction Thriller          Neil Burger
# ..                                       ...                  ...
# 80                                     Drama       Erwin brothers
# 81  Action Adventure Science Fiction Fantasy            Jon Watts
# 82                                       NaN       Lana Wachowski
# 83             Music Animation Comedy Family       Garth Jennings
# 84                                       NaN                  nan
#
#            actor_1_name       actor_2_name           actor_3_name
# 0            Idris Elba   Caleb McLaughlin         Jharrel Jerome
# 1   Jeffrey Dean Morgan      Katie Aselton         William Sadler
# 2         Casey Affleck        Sam Claflin        Veronica Ferres
# 3         Rachel Sennot       Molly Gordon           Polly Draper
# 4          Tye Sheridan     Lily-Rose Depp        Fionn Whitehead
# ..                  ...                ...                    ...
# 80         Zachary Levi        Anna Paquin       Ser'Darius Blain
# 81          Tom Holland            Zendaya          Jacob Batalon
# 82         Keanu Reeves   Carrie-Anne Moss  Yahya Abdul-Mateen II
# 83  Matthew McConaughey  Reese Witherspoon     Scarlett Johansson
# 84                  nan                NaN                    NaN
#
# [85 rows x 7 columns]

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df21
# Out:
#           director_name         actor_1_name       actor_2_name  \
# 0           Ricky Staub           Idris Elba   Caleb McLaughlin
# 1   Evan Spiliotopoulos  Jeffrey Dean Morgan      Katie Aselton
# 2          Vaughn Stein        Casey Affleck        Sam Claflin
# 3         Emma Seligman        Rachel Sennot       Molly Gordon
# 4           Neil Burger         Tye Sheridan     Lily-Rose Depp
# ..                  ...                  ...                ...
# 80       Erwin brothers         Zachary Levi        Anna Paquin
# 81            Jon Watts          Tom Holland            Zendaya
# 82       Lana Wachowski         Keanu Reeves   Carrie-Anne Moss
# 83       Garth Jennings  Matthew McConaughey  Reese Witherspoon
# 84                  nan                  nan                NaN
#
#              actor_3_name                                    genres  \
# 0          Jharrel Jerome                             Drama Western
# 1          William Sadler                                    Horror
# 2         Veronica Ferres                                  Thriller
# 3            Polly Draper                              Comedy Drama
# 4         Fionn Whitehead                  Science Fiction Thriller
# ..                    ...                                       ...
# 80       Ser'Darius Blain                                     Drama
# 81          Jacob Batalon  Action Adventure Science Fiction Fantasy
# 82  Yahya Abdul-Mateen II                                       NaN
# 83     Scarlett Johansson             Music Animation Comedy Family
# 84                    NaN                                       NaN
#
#                                  movie_title
# 0                            Concrete Cowboy
# 1                                 The Unholy
# 2                      Every Breath You Take
# 3                                 Shiva Baby
# 4                                   Voyagers
# ..                                       ...
# 80  American Underdog: The Kurt Warner Story
# 81                   Spider-Man: No Way Home
# 82               Untitled fourth Matrix film
# 83                                    Sing 2
# 84                                       NaN
#
# [85 rows x 6 columns]

# %%
new_df21['director_name'] = new_df21['director_name'].replace(np.nan, 'unknown')
new_df21['actor_1_name'] = new_df21['actor_1_name'].replace(np.nan, 'unknown')
new_df21['actor_2_name'] = new_df21['actor_2_name'].replace(np.nan, 'unknown')
new_df21['actor_3_name'] = new_df21['actor_3_name'].replace(np.nan, 'unknown')
new_df21['genres'] = new_df21['genres'].replace(np.nan, 'unknown')
new_df21['movie_title'] = new_df21['movie_title'].replace(np.nan, 'unknown')

# %%
new_df21['comb'] = new_df21['actor_1_name'] + ' ' + new_df21['actor_2_name'] + ' '+ new_df21['actor_3_name'] + ' '+ new_df21['director_name'] +' ' + new_df21['genres']

# %%
new_df21.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df21 = new_df21.dropna(how='any')

# %%
new_df21.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df21['movie_title'] = new_df21['movie_title'].str.lower()

# %%
new_df21
# Out:
#           director_name         actor_1_name       actor_2_name  \
# 0           Ricky Staub           Idris Elba   Caleb McLaughlin
# 1   Evan Spiliotopoulos  Jeffrey Dean Morgan      Katie Aselton
# 2          Vaughn Stein        Casey Affleck        Sam Claflin
# 3         Emma Seligman        Rachel Sennot       Molly Gordon
# 4           Neil Burger         Tye Sheridan     Lily-Rose Depp
# ..                  ...                  ...                ...
# 80       Erwin brothers         Zachary Levi        Anna Paquin
# 81            Jon Watts          Tom Holland            Zendaya
# 82       Lana Wachowski         Keanu Reeves   Carrie-Anne Moss
# 83       Garth Jennings  Matthew McConaughey  Reese Witherspoon
# 84                  nan                  nan            unknown
#
#              actor_3_name                                    genres  \
# 0          Jharrel Jerome                             Drama Western
# 1          William Sadler                                    Horror
# 2         Veronica Ferres                                  Thriller
# 3            Polly Draper                              Comedy Drama
# 4         Fionn Whitehead                  Science Fiction Thriller
# ..                    ...                                       ...
# 80       Ser'Darius Blain                                     Drama
# 81          Jacob Batalon  Action Adventure Science Fiction Fantasy
# 82  Yahya Abdul-Mateen II                                   unknown
# 83     Scarlett Johansson             Music Animation Comedy Family
# 84                unknown                                   unknown
#
#                                  movie_title  \
# 0                            concrete cowboy
# 1                                 the unholy
# 2                      every breath you take
# 3                                 shiva baby
# 4                                   voyagers
# ..                                       ...
# 80  american underdog: the kurt warner story
# 81                   spider-man: no way home
# 82               untitled fourth matrix film
# 83                                    sing 2
# 84                                   unknown
#
#                                                  comb
# 0   Idris Elba Caleb McLaughlin Jharrel Jerome Ric...
# 1   Jeffrey Dean Morgan Katie Aselton William Sadl...
# 2   Casey Affleck Sam Claflin Veronica Ferres Vaug...
# 3   Rachel Sennot Molly Gordon Polly Draper Emma S...
# 4   Tye Sheridan Lily-Rose Depp Fionn Whitehead Ne...
# ..                                                ...
# 80  Zachary Levi Anna Paquin Ser'Darius Blain Erwi...
# 81  Tom Holland Zendaya Jacob Batalon Jon Watts Ac...
# 82  Keanu Reeves Carrie-Anne Moss Yahya Abdul-Mate...
# 83  Matthew McConaughey Reese Witherspoon Scarlett...
# 84                    nan unknown unknown nan unknown
#
# [85 rows x 7 columns]

# %%
final_df = old_df.append(new_df21,ignore_index=True)

# %%
final_df
# Out:
#           director_name         actor_1_name       actor_2_name  \
# 0         James Cameron          CCH Pounder   Joel David Moore
# 1        Gore Verbinski          Johnny Depp      Orlando Bloom
# 2            Sam Mendes      Christoph Waltz       Rory Kinnear
# 3     Christopher Nolan            Tom Hardy     Christian Bale
# 4           Doug Walker          Doug Walker         Rob Walker
# ...                 ...                  ...                ...
# 6195     Erwin brothers         Zachary Levi        Anna Paquin
# 6196          Jon Watts          Tom Holland            Zendaya
# 6197     Lana Wachowski         Keanu Reeves   Carrie-Anne Moss
# 6198     Garth Jennings  Matthew McConaughey  Reese Witherspoon
# 6199                nan                  nan            unknown
#
#                actor_3_name                                    genres  \
# 0                 Wes Studi           Action Adventure Fantasy Sci-Fi
# 1            Jack Davenport                  Action Adventure Fantasy
# 2          Stephanie Sigman                 Action Adventure Thriller
# 3      Joseph Gordon-Levitt                           Action Thriller
# 4                   unknown                               Documentary
# ...                     ...                                       ...
# 6195       Ser'Darius Blain                                     Drama
# 6196          Jacob Batalon  Action Adventure Science Fiction Fantasy
# 6197  Yahya Abdul-Mateen II                                   unknown
# 6198     Scarlett Johansson             Music Animation Comedy Family
# 6199                unknown                                   unknown
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6195           american underdog: the kurt warner story
# 6196                            spider-man: no way home
# 6197                        untitled fourth matrix film
# 6198                                             sing 2
# 6199                                            unknown
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6195  Zachary Levi Anna Paquin Ser'Darius Blain Erwi...
# 6196  Tom Holland Zendaya Jacob Batalon Jon Watts Ac...
# 6197  Keanu Reeves Carrie-Anne Moss Yahya Abdul-Mate...
# 6198  Matthew McConaughey Reese Witherspoon Scarlett...
# 6199                    nan unknown unknown nan unknown
#
# [6200 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
